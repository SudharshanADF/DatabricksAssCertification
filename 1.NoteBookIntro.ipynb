# %% [markdown]
# # Introduction
# ## Databricks
# ### Certification

# %%
print("Hello world")

# %%
# %fs
ls dbfs:/databricks-datasets/COVID/

# %%
# %sh
ps

# %%
pip list

# %%
# %pip install faker

# %% [markdown]
# ##### %run: Import/Include another Notebook into current notebook

# %%
# %run "/Workspace/Users/sudarshan.reddy@finergytechsquadgmail.onmicrosoft.com/Certification/test/1.1.ChilNoteBook"

# %%
env

# %%
print_env_info()
